# %% [markdown]
# # Prepare Presentation layer

# %% [markdown]
# ### Step 1 - Import all required tables

# %%
# %run "../includes/configuration"

# %%
circuits_df = spark.read.parquet(f"{processed_folder_path}/circuits.parquet")

# %%
drivers_df = spark.read.parquet(f"{processed_folder_path}/drivers.parquet")

# %%
constructors_df = spark.read.parquet(f"{processed_folder_path}/constructors.parquet")

# %%
races_df = spark.read.parquet(f"{processed_folder_path}/races.parquet")

# %%
results_df = spark.read.parquet(f"{processed_folder_path}/results.parquet")

# %%
results_df.show(5)
# Out:
# +---------+---------+--------------+------+----+--------+-------------+--------------+------+----+----------+------------+-----------+----+----------------+-----------------+---+--------------------+-------+
# |result_id|driver_id|constructor_id|number|grid|position|position_text|position_order|points|laps|      time|milliseconds|fastest_lap|rank|fastest_lap_time|fastest_lap_speed|env|      ingestion_date|race_id|
# +---------+---------+--------------+------+----+--------+-------------+--------------+------+----+----------+------------+-----------+----+----------------+-----------------+---+--------------------+-------+
# |    19232|      657|           113|    14|  19|       1|            1|             1|   8.0| 200|3:49:17.27|    13757270|       null|null|              \N|               \N|Dev|2023-06-02 21:03:...|    800|
# |    19233|      525|           114|     9|   3|       2|            2|             2|   6.0| 200|  +1:09.95|    13827220|       null|null|              \N|               \N|Dev|2023-06-02 21:03:...|    800|
# |    19234|      658|           113|     2|   1|       3|            3|             3|   5.0| 200|  +1:19.73|    13837000|       null|null|              \N|               \N|Dev|2023-06-02 21:03:...|    800|
# |    19235|      526|           113|    34|  11|       4|            4|             4|   1.5| 200|  +2:52.68|    13929950|       null|null|              \N|               \N|Dev|2023-06-02 21:03:...|    800|
# |    19236|      673|           113|    73|  14|       5|            5|             5|   2.0| 200|  +3:24.55|    13961820|       null|null|              \N|               \N|Dev|2023-06-02 21:03:...|    800|
# +---------+---------+--------------+------+----+--------+-------------+--------------+------+----+----------+------------+-----------+----+----------------+-----------------+---+--------------------+-------+
# only showing top 5 rows

# %% [markdown]
# ### Step 2 - Select required columns after joining tables

# %%
from pyspark.sql import functions as f

# %%
final_df = results_df.join(races_df, results_df.race_id == races_df.race_id, "left") \
                .join(drivers_df, results_df.driver_id == drivers_df.driver_id, "left") \
                .join(constructors_df, results_df.constructor_id == constructors_df.constructor_id, "left") \
                .join(circuits_df, races_df.circuit_id == circuits_df.circuit_id, "left") \
                .withColumn("created_date", f.current_timestamp()) \
                .select(races_df.race_year, races_df.name.alias("race_name"), f.to_date(races_df.race_timestamp).alias("race_date"), circuits_df.location.alias("circuit_location") \
                        , drivers_df.name.alias("driver_name"), drivers_df.number.alias("driver_number"), drivers_df.nationality.alias("driver_nationality"), constructors_df.name.alias("team") \
                        ,results_df.grid, results_df.fastest_lap, results_df.time.alias("race_time"), results_df.points)

# %%
# display(final_df)
final_df.show(5)
# Out:
# +---------+----------------+---------+----------------+-------------+-------------+------------------+------------+----+-----------+----------+------+
# |race_year|       race_name|race_date|circuit_location|  driver_name|driver_number|driver_nationality|        team|grid|fastest_lap| race_time|points|
# +---------+----------------+---------+----------------+-------------+-------------+------------------+------------+----+-----------+----------+------+
# |     1954|Indianapolis 500|     null|    Indianapolis|Bill Vukovich|         null|          American|Kurtis Kraft|  19|       null|3:49:17.27|   8.0|
# |     1954|Indianapolis 500|     null|    Indianapolis|  Jimmy Bryan|         null|          American|       Kuzma|   3|       null|  +1:09.95|   6.0|
# |     1954|Indianapolis 500|     null|    Indianapolis| Jack McGrath|         null|          American|Kurtis Kraft|   1|       null|  +1:19.73|   5.0|
# |     1954|Indianapolis 500|     null|    Indianapolis| Troy Ruttman|         null|          American|Kurtis Kraft|  11|       null|  +2:52.68|   1.5|
# |     1954|Indianapolis 500|     null|    Indianapolis| Mike Nazaruk|         null|          American|Kurtis Kraft|  14|       null|  +3:24.55|   2.0|
# +---------+----------------+---------+----------------+-------------+-------------+------------------+------------+----+-----------+----------+------+
# only showing top 5 rows

# %% [markdown]
# ### Step 3 - Write data to the presentation layer

# %%
# Prepare the data for the visualization used on the site - https://www.bbc.com/sport/formula1/2020/abu-dhabi-grand-prix/results
display(final_df.filter("race_year = 2020 and race_name = 'Abu Dhabi Grand Prix'").orderBy(final_df.points.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_year</th><th>race_name</th><th>race_date</th><th>circuit_location</th><th>driver_name</th><th>driver_number</th><th>driver_nationality</th><th>team</th><th>grid</th><th>fastest_lap</th><th>race_time</th><th>points</th></tr></thead><tbody><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Max Verstappen</td><td>33</td><td>Dutch</td><td>Red Bull</td><td>1</td><td>14</td><td>1:36:28.645</td><td>25.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Valtteri Bottas</td><td>77</td><td>Finnish</td><td>Mercedes</td><td>2</td><td>40</td><td>+15.976</td><td>18.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Lewis Hamilton</td><td>44</td><td>British</td><td>Mercedes</td><td>3</td><td>37</td><td>+18.415</td><td>15.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Alexander Albon</td><td>23</td><td>Thai</td><td>Red Bull</td><td>5</td><td>42</td><td>+19.987</td><td>12.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Lando Norris</td><td>4</td><td>British</td><td>McLaren</td><td>4</td><td>53</td><td>+1:00.729</td><td>10.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Carlos Sainz</td><td>55</td><td>Spanish</td><td>McLaren</td><td>6</td><td>48</td><td>+1:05.662</td><td>8.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Daniel Ricciardo</td><td>3</td><td>Australian</td><td>Renault</td><td>11</td><td>55</td><td>+1:13.748</td><td>7.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Pierre Gasly</td><td>10</td><td>French</td><td>AlphaTauri</td><td>9</td><td>53</td><td>+1:29.718</td><td>4.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Esteban Ocon</td><td>31</td><td>French</td><td>Renault</td><td>10</td><td>47</td><td>+1:41.069</td><td>2.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Lance Stroll</td><td>18</td><td>Canadian</td><td>Racing Point</td><td>8</td><td>41</td><td>+1:42.738</td><td>1.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Daniil Kvyat</td><td>26</td><td>Russian</td><td>AlphaTauri</td><td>7</td><td>47</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Kimi Räikkönen</td><td>7</td><td>Finnish</td><td>Alfa Romeo</td><td>15</td><td>53</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Charles Leclerc</td><td>16</td><td>Monegasque</td><td>Ferrari</td><td>12</td><td>24</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Sebastian Vettel</td><td>5</td><td>German</td><td>Ferrari</td><td>13</td><td>37</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>George Russell</td><td>63</td><td>British</td><td>Williams</td><td>16</td><td>54</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Antonio Giovinazzi</td><td>99</td><td>Italian</td><td>Alfa Romeo</td><td>14</td><td>29</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Nicholas Latifi</td><td>6</td><td>Canadian</td><td>Williams</td><td>18</td><td>49</td><td>\N</td><td>0.0</td></tr><tr><td>2020</td><td>Abu Dhabi Grand Prix</td><td>2020-12-13</td><td>Abu Dhabi</td><td>Kevin Magnussen</td><td>20</td><td>Danish</td><td>Haas F1 Team</td><td>20</td><td>50</td ...

# %%
final_df.write.mode("overwrite").parquet(f"{presentation_folder_path}/race_results.parquet")
