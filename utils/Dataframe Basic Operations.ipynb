# %% [markdown]
# # Spark DataFrame Basic Operations

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('ops').getOrCreate()

# %%
df = spark.read.table('people', inferschema = True,

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df = spark.read.csv('/FileStore/tables/appl_stock.csv', inferSchema=True, header=True)

# %%
df.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %%
df.filter("close < 200").select(["open", "close"]).show()
# Out:
# +------------------+------------------+
# |              open|             close|
# +------------------+------------------+
# |206.78000600000001|            197.75|
# |        204.930004|        199.289995|
# |        201.079996|        192.060003|
# |192.36999699999998|        194.729998|
# |        195.909998|        195.859997|
# |        195.169994|        199.229994|
# |        196.730003|        192.050003|
# |192.63000300000002|        195.460001|
# |        195.690006|194.11999699999998|
# |        196.419996|196.19000400000002|
# |        195.889997|195.12000700000002|
# |        194.880001|        198.669994|
# |        199.999998|        197.059998|
# |         92.699997|         93.699997|
# |         94.730003|             94.25|
# |         94.129997|         93.860001|
# |         94.040001|         92.290001|
# |         92.199997|         91.279999|
# |         91.510002|         92.199997|
# |         92.309998| 92.08000200000001|
# +------------------+------------------+
# only showing top 20 rows

# %%
df1 = df.filter(df["close"] < 200).filter(df["open"] > 200).collect()

# %%
print(df1)
# Out:
# [Row(Date=datetime.date(2010, 1, 22), Open=206.78000600000001, High=207.499996, Low=197.16, Close=197.75, Volume=220441900, Adj Close=25.620401), Row(Date=datetime.date(2010, 1, 28), Open=204.930004, High=205.500004, Low=198.699995, Close=199.289995, Volume=293375600, Adj Close=25.819922000000002), Row(Date=datetime.date(2010, 1, 29), Open=201.079996, High=202.199995, Low=190.250002, Close=192.060003, Volume=311488100, Adj Close=24.883208)]
