# %% [markdown]
# # Data Ingestion Races

# %%
dbutils.widgets.dropdown("Environment", "Dev", ["Prod", "Dev", "Test"], "Environment")
env = dbutils.widgets.get("Environment")

# %%
# %run "../includes/configuration"

# %%
# %run "../includes/common_functions"

# %% [markdown]
# ### Step 1 - Import CSV data

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, TimestampType
from pyspark.sql.functions import current_timestamp, lit, concat, to_timestamp, substring

# %%
race_schema = StructType(fields=[StructField("raceId", IntegerType(), False),
                            StructField("year", IntegerType(), True),
                            StructField("round", IntegerType(), True),
                            StructField("circuitId", IntegerType(), True),
                            StructField("name", StringType(), True),
                            StructField("date", DateType(), True),
                            StructField("time", StringType(), True),
                            StructField("url", StringType(), True),
                           
                           ])

# %%
df = spark.read.csv(f"{raw_folder_path}/races.csv", header=True, schema=race_schema)

# %%
# display(df)
df.show(5)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|
# |     3|2009|    3|       17|  Chinese Grand Prix|2009-04-19|07:00:00|http://en.wikiped...|
# |     4|2009|    4|        3|  Bahrain Grand Prix|2009-04-26|12:00:00|http://en.wikiped...|
# |     5|2009|    5|        4|  Spanish Grand Prix|2009-05-10|12:00:00|http://en.wikiped...|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- raceId: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- round: integer (nullable = true)
#  |-- circuitId: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)

# %% [markdown]
# ### Step 2 - Transform data

# %%
transformed_df = df.withColumnRenamed("raceId", "race_id").withColumnRenamed("year", "race_year").withColumnRenamed("circuitId", "circuit_id").withColumn("env", lit(env)).withColumn("ingestion_date", current_timestamp()).drop("url")

# %%
# display(transformed_df)
transformed_df.show(5)
# Out:
# +-------+---------+-----+----------+--------------------+----------+--------+---+--------------------+
# |race_id|race_year|round|circuit_id|                name|      date|    time|env|      ingestion_date|
# +-------+---------+-----+----------+--------------------+----------+--------+---+--------------------+
# |      1|     2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|Dev|2023-06-02 21:02:...|
# |      2|     2009|    2|         2|Malaysian Grand Prix|2009-04-05|09:00:00|Dev|2023-06-02 21:02:...|
# |      3|     2009|    3|        17|  Chinese Grand Prix|2009-04-19|07:00:00|Dev|2023-06-02 21:02:...|
# |      4|     2009|    4|         3|  Bahrain Grand Prix|2009-04-26|12:00:00|Dev|2023-06-02 21:02:...|
# |      5|     2009|    5|         4|  Spanish Grand Prix|2009-05-10|12:00:00|Dev|2023-06-02 21:02:...|
# +-------+---------+-----+----------+--------------------+----------+--------+---+--------------------+
# only showing top 5 rows

# %%
final_df = transformed_df.select(transformed_df.race_id, transformed_df.race_year, transformed_df.round, transformed_df.circuit_id, transformed_df.name, to_timestamp(concat(transformed_df.date, lit(' '), substring(to_timestamp(transformed_df.time), 12, 9))).alias("race_timestamp"), transformed_df.ingestion_date)

# %%
# display(final_df)
final_df.show(5)
# Out:
# +-------+---------+-----+----------+--------------------+-------------------+--------------------+
# |race_id|race_year|round|circuit_id|                name|     race_timestamp|      ingestion_date|
# +-------+---------+-----+----------+--------------------+-------------------+--------------------+
# |      1|     2009|    1|         1|Australian Grand ...|2009-03-29 06:00:00|2023-06-02 21:02:...|
# |      2|     2009|    2|         2|Malaysian Grand Prix|2009-04-05 09:00:00|2023-06-02 21:02:...|
# |      3|     2009|    3|        17|  Chinese Grand Prix|2009-04-19 07:00:00|2023-06-02 21:02:...|
# |      4|     2009|    4|         3|  Bahrain Grand Prix|2009-04-26 12:00:00|2023-06-02 21:02:...|
# |      5|     2009|    5|         4|  Spanish Grand Prix|2009-05-10 12:00:00|2023-06-02 21:02:...|
# +-------+---------+-----+----------+--------------------+-------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### Step 3 - Load data into Data Lake

# %%
final_df.write.mode("overwrite").partitionBy('race_year').parquet(f"{processed_folder_path}/races.parquet")

# %%
# %fs
ls "/FileStore/tables"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/ContainsNull.csv</td><td>ContainsNull.csv</td><td>61</td><td>1685642371000</td></tr><tr><td>dbfs:/FileStore/tables/appl_stock.csv</td><td>appl_stock.csv</td><td>143130</td><td>1685638993000</td></tr><tr><td>dbfs:/FileStore/tables/circuits/</td><td>circuits/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/circuits.csv</td><td>circuits.csv</td><td>10044</td><td>1685665880000</td></tr><tr><td>dbfs:/FileStore/tables/circuits.parquet/</td><td>circuits.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/circuits1.parquet/</td><td>circuits1.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/circuits12/</td><td>circuits12/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/constructors.json</td><td>constructors.json</td><td>30415</td><td>1685706757000</td></tr><tr><td>dbfs:/FileStore/tables/constructors.parquet/</td><td>constructors.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/drivers.json</td><td>drivers.json</td><td>180812</td><td>1685707842000</td></tr><tr><td>dbfs:/FileStore/tables/drivers.parquet/</td><td>drivers.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/lap_times/</td><td>lap_times/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/lap_times.parquet/</td><td>lap_times.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/mydata.csv</td><td>mydata.csv</td><td>40</td><td>1685580057000</td></tr><tr><td>dbfs:/FileStore/tables/people-1.json</td><td>people-1.json</td><td>73</td><td>1685634520000</td></tr><tr><td>dbfs:/FileStore/tables/people-2.json</td><td>people-2.json</td><td>73</td><td>1685634612000</td></tr><tr><td>dbfs:/FileStore/tables/people.json</td><td>people.json</td><td>73</td><td>1685582820000</td></tr><tr><td>dbfs:/FileStore/tables/pit_stops-1.json</td><td>pit_stops-1.json</td><td>1369387</td><td>1685720766000</td></tr><tr><td>dbfs:/FileStore/tables/pit_stops.json</td><td>pit_stops.json</td><td>1369387</td><td>1685718585000</td></tr><tr><td>dbfs:/FileStore/tables/pit_stops.parquet/</td><td>pit_stops.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/qualifying/</td><td>qualifying/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/qualifying.parquet/</td><td>qualifying.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/races.csv</td><td>races.csv</td><td>116847</td><td>1685674099000</td></tr><tr><td>dbfs:/FileStore/tables/races.parquet/</td><td>races.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/results.json</td><td>results.json</td><td>7165641</td><td>1685715133000</td></tr><tr><td>dbfs:/FileStore/tables/results.parquet/</td><td>results.parquet/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/sales_info-1.csv</td><td>sales_info-1.csv</td><td>196</td><td>1685640537000</td></tr><tr><td>dbfs:/FileStore/tables/sales_info.csv</td><td>sales_info.csv</td><td>196</td><td>1685639045000</td></tr></tbody></table></div>

# %%
new_df = spark.read.parquet(f"{processed_folder_path}/races.parquet")

# %%
# display(new_df)
new_df.show(5)
# Out:
# +-------+-----+----------+--------------------+-------------------+--------------------+---------+
# |race_id|round|circuit_id|                name|     race_timestamp|      ingestion_date|race_year|
# +-------+-----+----------+--------------------+-------------------+--------------------+---------+
# |   1053|    2|        21|Emilia Romagna Gr...|2021-04-18 13:00:00|2023-06-02 21:02:...|     2021|
# |   1052|    1|         3|  Bahrain Grand Prix|2021-03-28 15:00:00|2023-06-02 21:02:...|     2021|
# |   1051|   21|         1|Australian Grand ...|2021-11-21 06:00:00|2023-06-02 21:02:...|     2021|
# |   1054|    3|        20|                 TBC|               null|2023-06-02 21:02:...|     2021|
# |   1055|    4|         4|  Spanish Grand Prix|2021-05-09 13:00:00|2023-06-02 21:02:...|     2021|
# +-------+-----+----------+--------------------+-------------------+--------------------+---------+
# only showing top 5 rows
